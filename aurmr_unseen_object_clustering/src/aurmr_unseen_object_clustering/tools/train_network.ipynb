# %%
#!/usr/bin/env python3

# Copyright (c) 2020 NVIDIA Corporation. All rights reserved.
# This work is licensed under the NVIDIA Source Code License - Non-commercial. Full
# text can be found in LICENSE.md

"""Train a UCN on image segmentation database."""

import torch
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data
from torch.utils.data import DataLoader, Dataset

import argparse
import pprint
import numpy as np
import sys
import os
import os.path as osp
import cv2
import matplotlib.pyplot as plt

import _init_paths
import datasets
import networks
from fcn.config import cfg, cfg_from_file, get_output_dir
from fcn.train import train_segnet
from datasets.factory import get_dataset
import h5py
import json
# Out:
# tabletop_object_train
# tabletop_object_test
# tabletop_object_all
# osd_object_test
# ocid_object_test

# %%
class binDataset(Dataset):
    def __init__(self, file):
        # Loads the data from the h5 file, where file is the path to the .h5 file
        self.file = h5py.File(file, 'r')
        self.len = self.file['frame0_data'].shape[0]
        self.name = '5k dataset'
        self.num_classes = 2
    
    def __len__(self):
        return self.len

    def add_noise_to_depth(self, depth_img, noise_params):
        """ Add noise to depth image. 
            This is adapted from the DexNet 2.0 code.
            Their code: https://github.com/BerkeleyAutomation/gqcnn/blob/75040b552f6f7fb264c27d427b404756729b5e88/gqcnn/sgd_optimizer.py

            @param depth_img: a [H x W] set of depth z values
        """
        depth_img = depth_img.copy()

        # Multiplicative noise: Gamma random variable
        multiplicative_noise = np.random.gamma(noise_params['gamma_shape'], noise_params['gamma_scale'])
        depth_img = multiplicative_noise * depth_img

        return depth_img

    def add_noise_to_xyz(self, xyz_img, depth_img, noise_params):
        """ Add (approximate) Gaussian Process noise to ordered point cloud

            @param xyz_img: a [H x W x 3] ordered point cloud
        """
        xyz_img = xyz_img.copy()

        H, W, C = xyz_img.shape

        # Additive noise: Gaussian process, approximated by zero-mean anisotropic Gaussian random variable,
        #                 which is rescaled with bicubic interpolation.
        gp_rescale_factor = np.random.randint(noise_params['gp_rescale_factor_range'][0],
                                            noise_params['gp_rescale_factor_range'][1])
        gp_scale = np.random.uniform(noise_params['gaussian_scale_range'][0],
                                    noise_params['gaussian_scale_range'][1])

        small_H, small_W = (np.array([H, W]) / gp_rescale_factor).astype(int)
        additive_noise = np.random.normal(loc=0.0, scale=gp_scale, size=(small_H, small_W, C))
        additive_noise = cv2.resize(additive_noise, (W, H), interpolation=cv2.INTER_CUBIC)
        xyz_img[depth_img > 0, :] += additive_noise[depth_img > 0, :]

        return xyz_img

    def dropout_random_ellipses(self, depth_img, noise_params):
        """ Randomly drop a few ellipses in the image for robustness.
            This is adapted from the DexNet 2.0 code.
            Their code: https://github.com/BerkeleyAutomation/gqcnn/blob/75040b552f6f7fb264c27d427b404756729b5e88/gqcnn/sgd_optimizer.py

            @param depth_img: a [H x W] set of depth z values
        """
        depth_img = depth_img.copy()

        # Sample number of ellipses to dropout
        num_ellipses_to_dropout = np.random.poisson(noise_params['ellipse_dropout_mean'])

        # Sample ellipse centers
        nonzero_pixel_indices = np.array(np.where(depth_img > 0)).T # Shape: [#nonzero_pixels x 2]
        dropout_centers_indices = np.random.choice(nonzero_pixel_indices.shape[0], size=num_ellipses_to_dropout)
        dropout_centers = nonzero_pixel_indices[dropout_centers_indices, :] # Shape: [num_ellipses_to_dropout x 2]

        # Sample ellipse radii and angles
        x_radii = np.random.gamma(noise_params['ellipse_gamma_shape'], noise_params['ellipse_gamma_scale'], size=num_ellipses_to_dropout)
        y_radii = np.random.gamma(noise_params['ellipse_gamma_shape'], noise_params['ellipse_gamma_scale'], size=num_ellipses_to_dropout)
        angles = np.random.randint(0, 360, size=num_ellipses_to_dropout)

        # Dropout ellipses
        for i in range(num_ellipses_to_dropout):
            center = dropout_centers[i, :]
            x_radius = np.round(x_radii[i]).astype(int)
            y_radius = np.round(y_radii[i]).astype(int)
            angle = angles[i]

            # dropout the ellipse
            mask = np.zeros_like(depth_img)
            mask = cv2.ellipse(mask, tuple(center[::-1]), (x_radius, y_radius), angle=angle, startAngle=0, endAngle=360, color=1, thickness=-1)
            depth_img[mask == 1] = 0

        return depth_img

    def random_color_warp(self, image, d_h=None, d_s=None, d_l=None):
        """ Given an RGB image [H x W x 3], add random hue, saturation and luminosity to the image

            Code adapted from: https://github.com/yuxng/PoseCNN/blob/master/lib/utils/blob.py
        """
        H, W, _ = image.shape

        image_color_warped = np.zeros_like(image)

        # Set random hue, luminosity and saturation which ranges from -0.1 to 0.1
        if d_h is None:
            d_h = (np.random.uniform() - 0.5) * 0.2 * 256
        if d_l is None:
            d_l = (np.random.uniform() - 0.5) * 0.2 * 256
        if d_s is None:
            d_s = (np.random.uniform() - 0.5) * 0.2 * 256

        # Convert the RGB to HLS
        hls = cv2.cvtColor(image.round().astype(np.uint8), cv2.COLOR_RGB2HLS)
        h, l, s = cv2.split(hls)

        # Add the values to the image H, L, S
        # new_h = (np.round((h + d_h)) % 256).astype(np.uint8)
        new_h = np.round(np.clip(h + d_h, 0, 255)).astype(np.uint8)
        new_l = np.round(np.clip(l + d_l, 0, 255)).astype(np.uint8)
        new_s = np.round(np.clip(s + d_s, 0, 255)).astype(np.uint8)

        # Convert the HLS to RGB
        new_hls = cv2.merge((new_h, new_l, new_s)).astype(np.uint8)
        new_im = cv2.cvtColor(new_hls, cv2.COLOR_HLS2RGB)

        image_color_warped = new_im.astype(np.float32)

        return image_color_warped

    # Computes point cloud from depth image and camera intrinsics
    def compute_xyz(self, depth_img, intrinsic):
        fx = intrinsic[0][0]
        fy = intrinsic[1][1]
        px = intrinsic[0][2]
        py = intrinsic[1][2]
        height, width = depth_img.shape

        indices = np.indices((height, width), dtype=np.float32).transpose(1,2,0)
        z_e = depth_img
        x_e = (indices[..., 1] - px) * z_e / fx
        y_e = (indices[..., 0] - py) * z_e / fy
        xyz_img = np.stack([x_e, y_e, z_e], axis=-1) # Shape: [H x W x 3]
        return xyz_img
    
    def __getitem__(self, index):
        cat = 'frame0_'

        # Loads the color image
        rgb = self.file[cat + 'data'][index][...,0:3]
        rgb = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)

        # Applies color jittering
        rgb = self.random_color_warp(rgb)

        # Loads the depth image and camera intrinsics
        depth = self.file[cat + 'depth'][index]
        depth[depth < -1000] = 0
        intrinsic = json.loads(self.file[cat + 'metadata'][index])['camera']['intrinsic_matrix']

        # Adds noise and cuts out random ellipses from depth
        depth = self.add_noise_to_depth(self.dropout_random_ellipses(depth, data_loading_params), data_loading_params)

        xyz = self.compute_xyz(depth, intrinsic).astype(np.float32)

        # Adds noise to the point cloud
        xyz = self.add_noise_to_xyz(xyz, depth, data_loading_params)

        # Loads the label masks
        label = self.file[cat + 'mask'][index]
        label = (label + 1) % 65536
        label %= np.max(label)

        # Randomly flip the image/point cloud/label
        if np.random.uniform() < .5:
            rgb = np.fliplr(rgb).copy()
            depth = np.fliplr(depth).copy()
            xyz = np.fliplr(xyz).copy()
            label = np.fliplr(label).copy()

        # Turn everything into tensors and reshape as needed
        im_tensor = torch.from_numpy(rgb) / 255.0
        pixel_mean = torch.tensor(cfg.PIXEL_MEANS / 255.0).float()
        im_tensor -= pixel_mean
        image_blob = im_tensor.permute(2, 0, 1)
        sample = {'image_color': image_blob}

        depth_blob = torch.from_numpy(xyz).permute(2, 0, 1)
        sample['depth'] = depth_blob
        label_blob = torch.from_numpy(label)
        sample['label'] = label_blob.unsqueeze(0)

        return sample

data_loading_params = {

# Camera/Frustum parameters
'img_width' : 256, 
'img_height' : 256,
'near' : 0.01,
'far' : 100,
'fov' : 45, # vertical field of view in degrees

'use_data_augmentation' : True,

# Multiplicative noise
'gamma_shape' : 1000.,
'gamma_scale' : 0.001,

# Additive noise
'gaussian_scale' : 0.005, # 5mm standard dev
'gp_rescale_factor' : 4,
'gaussian_scale_range' : [0., 0.003],
'gp_rescale_factor_range' : [12, 20],

# Random ellipse dropout
'ellipse_dropout_mean' : 10, 
'ellipse_gamma_shape' : 5.0, 
'ellipse_gamma_scale' : 1.0,

# Random high gradient dropout
'gradient_dropout_left_mean' : 15, 
'gradient_dropout_alpha' : 2., 
'gradient_dropout_beta' : 5.,

# Random pixel dropout
'pixel_dropout_alpha' : 1., 
'pixel_dropout_beta' : 10.,    
}

# %% [markdown]
# ## Sets parameters and performs the training loop

# %%
args = {'epochs':40000, 'startepoch':0, 'pretrained':None, 'cfg_file':None, 'solver':'sgd', 
'dataset_name':'shapenet_scene_train', 'dataset_background_name':'background_nvidia', 
'randomize':False, 'network_name':None, 'cad_name':None, 'pose_name':None}

args['network_name'] = 'seg_resnet34_8s_embedding'
args['cfg_file'] = '../experiments/cfgs/seg_resnet34_8s_embedding_cosine_rgbd_add_tabletop.yml'
args['solver'] = 'adam'
args['epochs'] = 24
BATCH_SIZE = 16


print('Called with args:')
print(args)

# Sets the config file
if args['cfg_file'] is not None:
    cfg_from_file(args['cfg_file'])

print('Using config:')
pprint.pprint(cfg)

# Sets random seeds (or not)
if not args['randomize']:
    # fix the random seeds (numpy and caffe) for reproducibility
    np.random.seed(cfg.RNG_SEED)

# Prepare dataset
cfg.MODE = 'TRAIN'
file_name = "/home/thomas/Desktop/aurmr_perception-master/outputs/train_shard_000000_prime.h5"
dataset = binDataset(file_name)
# worker_init_fn = dataset.worker_init_fn if hasattr(dataset, 'worker_init_fn') else None
num_workers = 4
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, 
    num_workers=num_workers)
print('Use dataset `{:s}` for training'.format(dataset.name))

output_dir = './output'
print('Output will be saved to `{:s}`'.format(output_dir))
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# prepare network
if args['pretrained']:
    network_data = torch.load(args['pretrained'])
    if isinstance(network_data, dict) and 'model' in network_data:
        network_data = network_data['model']
    print("=> using pre-trained network '{}'".format(args['network_name']))
else:
    network_data = None
    print("=> creating network '{}'".format(args['network_name']))

network = networks.__dict__[args['network_name']](dataset.num_classes, cfg.TRAIN.NUM_UNITS, network_data).cuda()
if torch.cuda.device_count() > 1:
    cfg.TRAIN.GPUNUM = torch.cuda.device_count()
    print("Let's use", torch.cuda.device_count(), "GPUs!")
network = torch.nn.DataParallel(network).cuda()
cudnn.benchmark = True

# prepare optimizer
assert(args['solver'] in ['adam', 'sgd'])
print('=> setting {} solver'.format(args['solver']))
param_groups = [{'params': network.module.bias_parameters(), 'weight_decay': cfg.TRAIN.WEIGHT_DECAY},
                {'params': network.module.weight_parameters(), 'weight_decay': cfg.TRAIN.WEIGHT_DECAY}]

if args['solver'] == 'adam':
    optimizer = torch.optim.Adam(param_groups, cfg.TRAIN.LEARNING_RATE,
                                    betas=(cfg.TRAIN.MOMENTUM, cfg.TRAIN.BETA))
elif args['solver'] == 'sgd':
    optimizer = torch.optim.SGD(param_groups, cfg.TRAIN.LEARNING_RATE,
                                momentum=cfg.TRAIN.MOMENTUM)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[m - args.startepoch for m in cfg.TRAIN.MILESTONES], gamma=cfg.TRAIN.GAMMA)
cfg.epochs = args['epochs']

# main loop
for epoch in range(args['startepoch'], args['epochs']):
    if args['solver'] == 'sgd':
        scheduler.step()

    # train for one epoch
    train_segnet(dataloader, network, optimizer, epoch)

    # save checkpoint
    if (epoch+1) % cfg.TRAIN.SNAPSHOT_EPOCHS == 0 or epoch == args['epochs'] - 1:
        state = network.module.state_dict()
        infix = ('_' + cfg.TRAIN.SNAPSHOT_INFIX
                    if cfg.TRAIN.SNAPSHOT_INFIX != '' else '')
        filename = ('trained_checkpoint_0.pth')
        torch.save(state, os.path.join(output_dir, filename))
        print(filename)
# Out:
# Called with args:
# {'epochs': 24, 'startepoch': 0, 'pretrained': None, 'cfg_file': '../experiments/cfgs/seg_resnet34_8s_embedding_cosine_rgbd_add_tabletop.yml', 'solver': 'adam', 'dataset_name': 'shapenet_scene_train', 'dataset_background_name': 'background_nvidia', 'randomize': False, 'network_name': 'seg_resnet34_8s_embedding', 'cad_name': None, 'pose_name': None}
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'BACKGROUND': '',
#  'CAD': '',
#  'DATA_PATH': '',
#  'EPS': 1e-14,
#  'EXP_DIR': 'tabletop_object',
#  'FEATURE_STRIDE': 16,
#  'FLIP_X': False,
#  'FLOW_HEIGHT': 512,
#  'FLOW_WIDTH': 640,
#  'GPU_ID': 0,
#  'INPUT': 'RGBD',
#  'INTRINSICS': [],
#  'MODE': 'TRAIN',
#  'NETWORK': 'VGG16',
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POSE': '',
#  'RIG': '',
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/home/thomas/Desktop/UnseenObjectClustering',
#  'TEST': {'ALIGN_Z_AXIS': False,
#           'BBOX_REG': True,
#           'BUILD_CODEBOOK': False,
#           'CHECK_SIZE': False,
#           'CLASSES': [0, 1, 2, 3],
#           'DET_THRESHOLD': 0.1,
#           'GAN': False,
#           'GEN_DATA': False,
#           'GLOBAL_SEARCH': False,
#           'GRID_SIZE': 256,
#           'HOUGH_INLIER_THRESHOLD': 0.9,
#           'HOUGH_LABEL_THRESHOLD': 100,
#           'HOUGH_SKIP_PIXELS': 10,
#           'HOUGH_VOTING_THRESHOLD': 10,
#           'IMS_PER_BATCH': 1,
#           'ITERNUM': 4,
#           'MEAN_SHIFT': False,
#           'NMS': 0.3,
#           'NUM_LOST': 3,
#           'NUM_SDF_ITERATIONS_INIT': 100,
#           'NUM_SDF_ITERATIONS_TRACKING': 50,
#           'POSE_CODEBOOK': False,
#           'POSE_REFINE': False,
#           'POSE_REG': False,
#           'POSE_SDF': True,
#           'RANSAC': False,
#           'ROS_CAMERA': 'D415',
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'SCALES_BASE': [1.0],
#           'SDF_ROTATION_REG': 0.1,
#           'SDF_TRANSLATION_REG': 10.0,
#           'SEGMENTATION': True,
#           'SINGLE_FRAME': True,
#           'SYMMETRY': [0, 0, 0, 0],
#           'SYNTHESIZE': True,
#           'VERTEX_REG_2D': False,
#           'VERTEX_REG_3D': False,
#           'VISUALIZE': True},
#  'TRAIN': {'ADAPT': False,
#            'ADAPT_NUM': 400,
#            'ADAPT_RATIO': 1,
#            'ADAPT_ROOT': '',
#            'ADAPT_WEIGHT': 0.1,
#            'ADD_NOISE': True,
#            'AFFINE': False,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BETA': 0.999,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.1,
#            'BOOSTRAP_PIXELS': 20,
#            'BOX_W': 1.0,
#            'CHANGE_BACKGROUND': False,
#            'CHROMATIC': True,
#            'CLASSES': [0, 1, 2, 3],
#            'DISPLAY': 20,
#            'EMBEDDING_ALPHA': 0.02,
#            'EMBEDDING_CONTRASTIVE': False,
#            'EMBEDDING_DELTA': 0.5,
#            'EMBEDDING_LAMBDA_INTER': 10.0,
#            'EMBEDDING_LAMBDA_INTRA': 10.0,
#            'EMBEDDING_LOSS_WEIGHT_BACKGROUND': 1.0,
#            'EMBEDDING_LOSS_WEIGHT_MATCH': 1.0,
#            'EMBEDDING_LOSS_WEIGHT_NONMATCH': 1.0,
#            'EMBEDDING_METRIC': 'cosine',
#            'EMBEDDING_NORMALIZATION': True,
#            'EMBEDDING_PIXELWISE': False,
#            'EMBEDDING_PRETRAIN': True,
#            'EMBEDDING_PROTOTYPE': False,
#            'EMBEDDING_SAMPLING': True,
#            'EMBEDDING_SAMPLING_NUM': 1000,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'FG_THRESH_POSE': 0.5,
#            'FREEZE_LAYERS': True,
#            'FUSION_TYPE': 'add',
#            'GAMMA': 0.1,
#            'GAN': False,
#            'GPUNUM': 1,
#            'GRID_SIZE': 256,
#            'HARD_ANGLE': 5.0,
#            'HARD_LABEL_SAMPLING': 0.0,
#            'HARD_LABEL_THRESHOLD': 0.9,
#            'HAS_RPN': True,
#            'HEATUP': 4,
#            'HOUGH_INLIER_THRESHOLD': 0.9,
#            'HOUGH_LABEL_THRESHOLD': 100,
#            'HOUGH_SKIP_PIXELS': 10,
#            'HOUGH_VOTING_THRESHOLD': 10,
#            'IMS_PER_BATCH': 16,
#            'ITERNUM': 4,
#            'ITERS': 0,
#            'LABEL_W': 1.0,
#            'LEARNING_RATE': 1e-05,
#            'MATCHING': False,
#            'MAX_ITERS_PER_EPOCH': 1000000,
#            'MILESTONES': [3],
#            'MOMENTUM': 0.9,
#            'NOISE_LEVEL': 0.05,
#            'NUM_STEPS': 5,
#            'NUM_UNITS': 64,
#            'OPTIMIZER': 'MOMENTUM',
#            'POSE_REG': False,
#            'POSE_W': 1.0,
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES_BASE': [1.0],
#            'SEGMENTATION': True,
#            'SINGLE_FRAME': False,
#            'SLIM': True,
#            'SNAPSHOT_EPOCHS': 1,
#            'SNAPSHOT_INFIX': 'resnet34_8s_embedding_cosine_rgbd_add_sampling',
#            'SNAPSHOT_PREFIX': 'seg',
#            'SYMMETRY': [0, 0, 0, 0],
#            'SYMSIZE': 0,
#            'SYNITER': 0,
#            'SYNNUM': 80000,
#            'SYNROOT': '/home/yuxiang/Projects/Deep_Pose/data/LOV/data_syn/',
#            'SYNTHESIZE': True,
#            'SYN_BACKGROUND_AFFINE': False,
#            'SYN_BACKGROUND_CONSTANT_PROB': 0.2,
#            'SYN_BACKGROUND_SPECIFIC': False,
#            'SYN_BACKGROUND_SUBTRACT_MEAN': True,
#            'SYN_BOUND': 0.05,
#            'SYN_CLASS_INDEX': 1,
#            'SYN_CROP': False,
#            'SYN_CROP_SIZE': 224,
#            'SYN_HEIGHT': 480,
#            'SYN_MAX_OBJECT': 5,
#            'SYN_MIN_OBJECT': 3,
#            'SYN_ONLINE': False,
#            'SYN_RATIO': 5,
#            'SYN_SAMPLE_DISTRACTOR': True,
#            'SYN_SAMPLE_OBJECT': True,
#            'SYN_SAMPLE_POSE': False,
#            'SYN_STD_ROTATION': 15,
#            'SYN_STD_TRANSLATION': 0.05,
#            'SYN_TABLE_PROB': 0.9,
#            'SYN_TFAR': 0.6,
#            'SYN_TNEAR': 0.2,
#            'SYN_WIDTH': 640,
#            'TRAINABLE': True,
#            'UNIFORM_POSE_INTERVAL': 15,
#            'USE_FLIPPED': False,
#            'USE_GT': False,
#            'VERTEX_REG': True,
#            'VERTEX_REG_DELTA': False,
#            'VERTEX_W': 1.0,
#            'VERTEX_W_INSIDE': 10.0,
#            'VISUALIZE': False,
#            'WEIGHT_DECAY': 0.0005,
#            'add_percentage_max': 0.4,
#            'add_percentage_min': 0.1,
#            'cut_percentage_max': 0.5,
#            'cut_percentage_min': 0.25,
#            'ellipse_gamma_base_scale': 1.0,
#            'ellipse_gamma_base_shape': 1.0,
#            'ellipse_size_percentage': 0.1,
#            'label_dilation_alpha': 1.0,
#            'label_dilation_beta': 19.0,
#            'max_augmentation_tries': 10,
#            'max_padding_percentage': 0.5,
#            'min_padding_percentage': 0.05,
#            'morphology_max_iters': 3,
#            'num_ellipses_mean': 3,
#            'padding_alpha': 1.0,
#            'padding_beta': 4.0,
#            'rate_of_ellipses': 0.8,
#            'rate_of_label_adding': 0.5,
#            'rate_of_label_cutting': 0.3,
#            'rate_of_morphological_transform': 0.9,
#            'rate_of_rotation': 0.7,
#            'rate_of_translation': 0.7,
#            'rotation_angle_max': 10,
#            'translation_alpha': 1.0,
#            'translation_beta': 19.0,
#            'translation_percentage_min': 0.05},
#  'USE_GPU_NMS': True,
#  'epochs': 24,
#  'gpu_id': 0,
#  'instance_id': 0}
# Use dataset `5k dataset` for training
# Output will be saved to `./output`
# => creating network 'seg_resnet34_8s_embedding'
# model keys
# =================================================
# conv1.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
# layer1.0.conv1.weight
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.num_batches_tracked
# layer1.0.conv2.weight
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.num_batches_tracked
# layer1.1.conv1.weight
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.num_batches_tracked
# layer1.1.conv2.weight
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# layer1.1.bn2.running_mean
# layer1.1.bn2.running_var
# layer1.1.bn2.num_batches_tracked
# layer1.2.conv1.weight
# layer1.2.bn1.weight
# layer1.2.bn1.bias
# layer1.2.bn1.running_mean
# layer1.2.bn1.running_var
# layer1.2.bn1.num_batches_tracked
# layer1.2.conv2.weight
# layer1.2.bn2.weight
# layer1.2.bn2.bias
# layer1.2.bn2.running_mean
# layer1.2.bn2.running_var
# layer1.2.bn2.num_batches_tracked
# layer2.0.conv1.weight
# layer2.0.bn1.weight
# layer2.0.bn1.bias
# layer2.0.bn1.running_mean
# layer2.0.bn1.running_var
# layer2.0.bn1.num_batches_tracked
# layer2.0.conv2.weight
# layer2.0.bn2.weight
# layer2.0.bn2.bias
# layer2.0.bn2.running_mean
# layer2.0.bn2.running_var
# layer2.0.bn2.num_batches_tracked
# layer2.0.downsample.0.weight
# layer2.0.downsample.1.weight
# layer2.0.downsample.1.bias
# layer2.0.downsample.1.running_mean
# layer2.0.downsample.1.running_var
# layer2.0.downsample.1.num_batches_tracked
# layer2.1.conv1.weight
# layer2.1.bn1.weight
# layer2.1.bn1.bias
# layer2.1.bn1.running_mean
# layer2.1.bn1.running_var
# layer2.1.bn1.num_batches_tracked
# layer2.1.conv2.weight
# layer2.1.bn2.weight
# layer2.1.bn2.bias
# layer2.1.bn2.running_mean
# layer2.1.bn2.running_var
# layer2.1.bn2.num_batches_tracked
# layer2.2.conv1.weight
# layer2.2.bn1.weight
# layer2.2.bn1.bias
# layer2.2.bn1.running_mean
# layer2.2.bn1.running_var
# layer2.2.bn1.num_batches_tracked
# layer2.2.conv2.weight
# layer2.2.bn2.weight
# layer2.2.bn2.bias
# layer2.2.bn2.running_mean
# layer2.2.bn2.running_var
# layer2.2.bn2.num_batches_tracked
# layer2.3.conv1.weight
# layer2.3.bn1.weight
# layer2.3.bn1.bias
# layer2.3.bn1.running_mean
# layer2.3.bn1.running_var
# layer2.3.bn1.num_batches_tracked
# layer2.3.conv2.weight
# layer2.3.bn2.weight
# layer2.3.bn2.bias
# layer2.3.bn2.running_mean
# layer2.3.bn2.running_var
# layer2.3.bn2.num_batches_tracked
# layer3.0.conv1.weight
# layer3.0.bn1.weight
# layer3.0.bn1.bias
# layer3.0.bn1.running_mean
# layer3.0.bn1.running_var
# layer3.0.bn1.num_batches_tracked
# layer3.0.conv2.weight
# layer3.0.bn2.weight
# layer3.0.bn2.bias
# layer3.0.bn2.running_mean
# layer3.0.bn2.running_var
# layer3.0.bn2.num_batches_tracked
# layer3.0.downsample.0.weight
# layer3.0.downsample.1.weight
# layer3.0.downsample.1.bias
# layer3.0.downsample.1.running_mean
# layer3.0.downsample.1.running_var
# layer3.0.downsample.1.num_batches_tracked
# layer3.1.conv1.weight
# layer3.1.bn1.weight
# layer3.1.bn1.bias
# layer3.1.bn1.running_mean
# layer3.1.bn1.running_var
# layer3.1.bn1.num_batches_tracked
# layer3.1.conv2.weight
# layer3.1.bn2.weight
# layer3.1.bn2.bias
# layer3.1.bn2.running_mean
# layer3.1.bn2.running_var
# layer3.1.bn2.num_batches_tracked
# layer3.2.conv1.weight
# layer3.2.bn1.weight
# layer3.2.bn1.bias
# layer3.2.bn1.running_mean
# layer3.2.bn1.running_var
# layer3.2.bn1.num_batches_tracked
# layer3.2.conv2.weight
# layer3.2.bn2.weight
# layer3.2.bn2.bias
# layer3.2.bn2.running_mean
# layer3.2.bn2.running_var
# layer3.2.bn2.num_batches_tracked
# layer3.3.conv1.weight
# layer3.3.bn1.weight
# layer3.3.bn1.bias
# layer3.3.bn1.running_mean
# layer3.3.bn1.running_var
# layer3.3.bn1.num_batches_tracked
# layer3.3.conv2.weight
# layer3.3.bn2.weight
# layer3.3.bn2.bias
# layer3.3.bn2.running_mean
# layer3.3.bn2.running_var
# layer3.3.bn2.num_batches_tracked
# layer3.4.conv1.weight
# layer3.4.bn1.weight
# layer3.4.bn1.bias
# layer3.4.bn1.running_mean
# layer3.4.bn1.running_var
# layer3.4.bn1.num_batches_tracked
# layer3.4.conv2.weight
# layer3.4.bn2.weight
# layer3.4.bn2.bias
# layer3.4.bn2.running_mean
# layer3.4.bn2.running_var
# layer3.4.bn2.num_batches_tracked
# layer3.5.conv1.weight
# layer3.5.bn1.weight
# layer3.5.bn1.bias
# layer3.5.bn1.running_mean
# layer3.5.bn1.running_var
# layer3.5.bn1.num_batches_tracked
# layer3.5.conv2.weight
# layer3.5.bn2.weight
# layer3.5.bn2.bias
# layer3.5.bn2.running_mean
# layer3.5.bn2.running_var
# layer3.5.bn2.num_batches_tracked
# layer4.0.conv1.weight
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.bn1.running_mean
# layer4.0.bn1.running_var
# layer4.0.bn1.num_batches_tracked
# layer4.0.conv2.weight
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.bn2.running_mean
# layer4.0.bn2.running_var
# layer4.0.bn2.num_batches_tracked
# layer4.0.downsample.0.weight
# layer4.0.downsample.1.weight
# layer4.0.downsample.1.bias
# layer4.0.downsample.1.running_mean
# layer4.0.downsample.1.running_var
# layer4.0.downsample.1.num_batches_tracked
# layer4.1.conv1.weight
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.bn1.running_mean
# layer4.1.bn1.running_var
# layer4.1.bn1.num_batches_tracked
# layer4.1.conv2.weight
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# layer4.1.bn2.running_mean
# layer4.1.bn2.running_var
# layer4.1.bn2.num_batches_tracked
# layer4.2.conv1.weight
# layer4.2.bn1.weight
# layer4.2.bn1.bias
# layer4.2.bn1.running_mean
# layer4.2.bn1.running_var
# layer4.2.bn1.num_batches_tracked
# layer4.2.conv2.weight
# layer4.2.bn2.weight
# layer4.2.bn2.bias
# layer4.2.bn2.running_mean
# layer4.2.bn2.running_var
# layer4.2.bn2.num_batches_tracked
# fc.weight
# fc.bias
# =================================================
# data keys
# =================================================
# conv1.weight
# bn1.running_mean
# bn1.running_var
# bn1.weight
# bn1.bias
# layer1.0.conv1.weight
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.conv2.weight
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.1.conv1.weight
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.conv2.weight
# layer1.1.bn2.running_mean
# layer1.1.bn2.running_var
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# layer1.2.conv1.weight
# layer1.2.bn1.running_mean
# layer1.2.bn1.running_var
# layer1.2.bn1.weight
# layer1.2.bn1.bias
# layer1.2.conv2.weight
# layer1.2.bn2.running_mean
# layer1.2.bn2.running_var
# layer1.2.bn2.weight
# layer1.2.bn2.bias
# layer2.0.conv1.weight
# layer2.0.bn1.running_mean
# layer2.0.bn1.running_var
# layer2.0.bn1.weight
# layer2.0.bn1.bias
# layer2.0.conv2.weight
# layer2.0.bn2.running_mean
# layer2.0.bn2.running_var
# layer2.0.bn2.weight
# layer2.0.bn2.bias
# layer2.0.downsample.0.weight
# layer2.0.downsample.1.running_mean
# layer2.0.downsample.1.running_var
# layer2.0.downsample.1.weight
# layer2.0.downsample.1.bias
# layer2.1.conv1.weight
# layer2.1.bn1.running_mean
# layer2.1.bn1.running_var
# layer2.1.bn1.weight
# layer2.1.bn1.bias
# layer2.1.conv2.weight
# layer2.1.bn2.running_mean
# layer2.1.bn2.running_var
# layer2.1.bn2.weight
# layer2.1.bn2.bias
# layer2.2.conv1.weight
# layer2.2.bn1.running_mean
# layer2.2.bn1.running_var
# layer2.2.bn1.weight
# layer2.2.bn1.bias
# layer2.2.conv2.weight
# layer2.2.bn2.running_mean
# layer2.2.bn2.running_var
# layer2.2.bn2.weight
# layer2.2.bn2.bias
# layer2.3.conv1.weight
# layer2.3.bn1.running_mean
# layer2.3.bn1.running_var
# layer2.3.bn1.weight
# layer2.3.bn1.bias
# layer2.3.conv2.weight
# layer2.3.bn2.running_mean
# layer2.3.bn2.running_var
# layer2.3.bn2.weight
# layer2.3.bn2.bias
# layer3.0.conv1.weight
# layer3.0.bn1.running_mean
# layer3.0.bn1.running_var
# layer3.0.bn1.weight
# layer3.0.bn1.bias
# layer3.0.conv2.weight
# layer3.0.bn2.running_mean
# layer3.0.bn2.running_var
# layer3.0.bn2.weight
# layer3.0.bn2.bias
# layer3.0.downsample.0.weight
# layer3.0.downsample.1.running_mean
# layer3.0.downsample.1.running_var
# layer3.0.downsample.1.weight
# layer3.0.downsample.1.bias
# layer3.1.conv1.weight
# layer3.1.bn1.running_mean
# layer3.1.bn1.running_var
# layer3.1.bn1.weight
# layer3.1.bn1.bias
# layer3.1.conv2.weight
# layer3.1.bn2.running_mean
# layer3.1.bn2.running_var
# layer3.1.bn2.weight
# layer3.1.bn2.bias
# layer3.2.conv1.weight
# layer3.2.bn1.running_mean
# layer3.2.bn1.running_var
# layer3.2.bn1.weight
# layer3.2.bn1.bias
# layer3.2.conv2.weight
# layer3.2.bn2.running_mean
# layer3.2.bn2.running_var
# layer3.2.bn2.weight
# layer3.2.bn2.bias
# layer3.3.conv1.weight
# layer3.3.bn1.running_mean
# layer3.3.bn1.running_var
# layer3.3.bn1.weight
# layer3.3.bn1.bias
# layer3.3.conv2.weight
# layer3.3.bn2.running_mean
# layer3.3.bn2.running_var
# layer3.3.bn2.weight
# layer3.3.bn2.bias
# layer3.4.conv1.weight
# layer3.4.bn1.running_mean
# layer3.4.bn1.running_var
# layer3.4.bn1.weight
# layer3.4.bn1.bias
# layer3.4.conv2.weight
# layer3.4.bn2.running_mean
# layer3.4.bn2.running_var
# layer3.4.bn2.weight
# layer3.4.bn2.bias
# layer3.5.conv1.weight
# layer3.5.bn1.running_mean
# layer3.5.bn1.running_var
# layer3.5.bn1.weight
# layer3.5.bn1.bias
# layer3.5.conv2.weight
# layer3.5.bn2.running_mean
# layer3.5.bn2.running_var
# layer3.5.bn2.weight
# layer3.5.bn2.bias
# layer4.0.conv1.weight
# layer4.0.bn1.running_mean
# layer4.0.bn1.running_var
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.conv2.weight
# layer4.0.bn2.running_mean
# layer4.0.bn2.running_var
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.downsample.0.weight
# layer4.0.downsample.1.running_mean
# layer4.0.downsample.1.running_var
# layer4.0.downsample.1.weight
# layer4.0.downsample.1.bias
# layer4.1.conv1.weight
# layer4.1.bn1.running_mean
# layer4.1.bn1.running_var
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.conv2.weight
# layer4.1.bn2.running_mean
# layer4.1.bn2.running_var
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# layer4.2.conv1.weight
# layer4.2.bn1.running_mean
# layer4.2.bn1.running_var
# layer4.2.bn1.weight
# layer4.2.bn1.bias
# layer4.2.conv2.weight
# layer4.2.bn2.running_mean
# layer4.2.bn2.running_var
# layer4.2.bn2.weight
# layer4.2.bn2.bias
# fc.weight
# fc.bias
# =================================================
# load the following keys from the pretrained model
# =================================================
# conv1.weight
# bn1.running_mean
# bn1.running_var
# bn1.weight
# bn1.bias
# layer1.0.conv1.weight
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.conv2.weight
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.1.conv1.weight
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.conv2.weight
# layer1.1.bn2.running_mean
# layer1.1.bn2.running_var
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# layer1.2.conv1.weight
# layer1.2.bn1.running_mean
# layer1.2.bn1.running_var
# layer1.2.bn1.weight
# layer1.2.bn1.bias
# layer1.2.conv2.weight
# layer1.2.bn2.running_mean
# layer1.2.bn2.running_var
# layer1.2.bn2.weight
# layer1.2.bn2.bias
# layer2.0.conv1.weight
# layer2.0.bn1.running_mean
# layer2.0.bn1.running_var
# layer2.0.bn1.weight
# layer2.0.bn1.bias
# layer2.0.conv2.weight
# layer2.0.bn2.running_mean
# layer2.0.bn2.running_var
# layer2.0.bn2.weight
# layer2.0.bn2.bias
# layer2.0.downsample.0.weight
# layer2.0.downsample.1.running_mean
# layer2.0.downsample.1.running_var
# layer2.0.downsample.1.weight
# layer2.0.downsample.1.bias
# layer2.1.conv1.weight
# layer2.1.bn1.running_mean
# layer2.1.bn1.running_var
# layer2.1.bn1.weight
# layer2.1.bn1.bias
# layer2.1.conv2.weight
# layer2.1.bn2.running_mean
# layer2.1.bn2.running_var
# layer2.1.bn2.weight
# layer2.1.bn2.bias
# layer2.2.conv1.weight
# layer2.2.bn1.running_mean
# layer2.2.bn1.running_var
# layer2.2.bn1.weight
# layer2.2.bn1.bias
# layer2.2.conv2.weight
# layer2.2.bn2.running_mean
# layer2.2.bn2.running_var
# layer2.2.bn2.weight
# layer2.2.bn2.bias
# layer2.3.conv1.weight
# layer2.3.bn1.running_mean
# layer2.3.bn1.running_var
# layer2.3.bn1.weight
# layer2.3.bn1.bias
# layer2.3.conv2.weight
# layer2.3.bn2.running_mean
# layer2.3.bn2.running_var
# layer2.3.bn2.weight
# layer2.3.bn2.bias
# layer3.0.conv1.weight
# layer3.0.bn1.running_mean
# layer3.0.bn1.running_var
# layer3.0.bn1.weight
# layer3.0.bn1.bias
# layer3.0.conv2.weight
# layer3.0.bn2.running_mean
# layer3.0.bn2.running_var
# layer3.0.bn2.weight
# layer3.0.bn2.bias
# layer3.0.downsample.0.weight
# layer3.0.downsample.1.running_mean
# layer3.0.downsample.1.running_var
# layer3.0.downsample.1.weight
# layer3.0.downsample.1.bias
# layer3.1.conv1.weight
# layer3.1.bn1.running_mean
# layer3.1.bn1.running_var
# layer3.1.bn1.weight
# layer3.1.bn1.bias
# layer3.1.conv2.weight
# layer3.1.bn2.running_mean
# layer3.1.bn2.running_var
# layer3.1.bn2.weight
# layer3.1.bn2.bias
# layer3.2.conv1.weight
# layer3.2.bn1.running_mean
# layer3.2.bn1.running_var
# layer3.2.bn1.weight
# layer3.2.bn1.bias
# layer3.2.conv2.weight
# layer3.2.bn2.running_mean
# layer3.2.bn2.running_var
# layer3.2.bn2.weight
# layer3.2.bn2.bias
# layer3.3.conv1.weight
# layer3.3.bn1.running_mean
# layer3.3.bn1.running_var
# layer3.3.bn1.weight
# layer3.3.bn1.bias
# layer3.3.conv2.weight
# layer3.3.bn2.running_mean
# layer3.3.bn2.running_var
# layer3.3.bn2.weight
# layer3.3.bn2.bias
# layer3.4.conv1.weight
# layer3.4.bn1.running_mean
# layer3.4.bn1.running_var
# layer3.4.bn1.weight
# layer3.4.bn1.bias
# layer3.4.conv2.weight
# layer3.4.bn2.running_mean
# layer3.4.bn2.running_var
# layer3.4.bn2.weight
# layer3.4.bn2.bias
# layer3.5.conv1.weight
# layer3.5.bn1.running_mean
# layer3.5.bn1.running_var
# layer3.5.bn1.weight
# layer3.5.bn1.bias
# layer3.5.conv2.weight
# layer3.5.bn2.running_mean
# layer3.5.bn2.running_var
# layer3.5.bn2.weight
# layer3.5.bn2.bias
# layer4.0.conv1.weight
# layer4.0.bn1.running_mean
# layer4.0.bn1.running_var
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.conv2.weight
# layer4.0.bn2.running_mean
# layer4.0.bn2.running_var
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.downsample.0.weight
# layer4.0.downsample.1.running_mean
# layer4.0.downsample.1.running_var
# layer4.0.downsample.1.weight
# layer4.0.downsample.1.bias
# layer4.1.conv1.weight
# layer4.1.bn1.running_mean
# layer4.1.bn1.running_var
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.conv2.weight
# layer4.1.bn2.running_mean
# layer4.1.bn2.running_var
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# layer4.2.conv1.weight
# layer4.2.bn1.running_mean
# layer4.2.bn1.running_var
# layer4.2.bn1.weight
# layer4.2.bn1.bias
# layer4.2.conv2.weight
# layer4.2.bn2.running_mean
# layer4.2.bn2.running_var
# layer4.2.bn2.weight
# layer4.2.bn2.bias
# fc.weight
# fc.bias
# =================================================
# =============no pretrained weights===============
# model keys
# =================================================
# fcn.resnet34_8s.conv1.weight
# fcn.resnet34_8s.bn1.weight
# fcn.resnet34_8s.bn1.bias
# fcn.resnet34_8s.bn1.running_mean
# fcn.resnet34_8s.bn1.running_var
# fcn.resnet34_8s.bn1.num_batches_tracked
# fcn.resnet34_8s.layer1.0.conv1.weight
# fcn.resnet34_8s.layer1.0.bn1.weight
# fcn.resnet34_8s.layer1.0.bn1.bias
# fcn.resnet34_8s.layer1.0.bn1.running_mean
# fcn.resnet34_8s.layer1.0.bn1.running_var
# fcn.resnet34_8s.layer1.0.bn1.num_batches_tracked
# fcn.resnet34_8s.layer1.0.conv2.weight
# fcn.resnet34_8s.layer1.0.bn2.weight
# fcn.resnet34_8s.layer1.0.bn2.bias
# fcn.resnet34_8s.layer1.0.bn2.running_mean
# fcn.resnet34_8s.layer1.0.bn2.running_var
# fcn.resnet34_8s.layer1.0.bn2.num_batches_tracked
# fcn.resnet34_8s.layer1.1.conv1.weight
# fcn.resnet34_8s.layer1.1.bn1.weight
# fcn.resnet34_8s.layer1.1.bn1.bias
# fcn.resnet34_8s.layer1.1.bn1.running_mean
# fcn.resnet34_8s.layer1.1.bn1.running_var
# fcn.resnet34_8s.layer1.1.bn1.num_batches_tracked
# fcn.resnet34_8s.layer1.1.conv2.weight
# fcn.resnet34_8s.layer1.1.bn2.weight
# fcn.resnet34_8s.layer1.1.bn2.bias
# fcn.resnet34_8s.layer1.1.bn2.running_mean
# fcn.resnet34_8s.layer1.1.bn2.running_var
# fcn.resnet34_8s.layer1.1.bn2.num_batches_tracked
# fcn.resnet34_8s.layer1.2.conv1.weight
# fcn.resnet34_8s.layer1.2.bn1.weight
# fcn.resnet34_8s.layer1.2.bn1.bias
# fcn.resnet34_8s.layer1.2.bn1.running_mean
# fcn.resnet34_8s.layer1.2.bn1.running_var
# fcn.resnet34_8s.layer1.2.bn1.num_batches_tracked
# fcn.resnet34_8s.layer1.2.conv2.weight
# fcn.resnet34_8s.layer1.2.bn2.weight
# fcn.resnet34_8s.layer1.2.bn2.bias
# fcn.resnet34_8s.layer1.2.bn2.running_mean
# fcn.resnet34_8s.layer1.2.bn2.running_var
# fcn.resnet34_8s.layer1.2.bn2.num_batches_tracked
# fcn.resnet34_8s.layer2.0.conv1.weight
# fcn.resnet34_8s.layer2.0.bn1.weight
# fcn.resnet34_8s.layer2.0.bn1.bias
# fcn.resnet34_8s.layer2.0.bn1.running_mean
# fcn.resnet34_8s.layer2.0.bn1.running_var
# fcn.resnet34_8s.layer2.0.bn1.num_batches_tracked
# fcn.resnet34_8s.layer2.0.conv2.weight
# fcn.resnet34_8s.layer2.0.bn2.weight
# fcn.resnet34_8s.layer2.0.bn2.bias
# fcn.resnet34_8s.layer2.0.bn2.running_mean
# fcn.resnet34_8s.layer2.0.bn2.running_var
# fcn.resnet34_8s.layer2.0.bn2.num_batches_tracked
# fcn.resnet34_8s.layer2.0.downsample.0.weight
# fcn.resnet34_8s.layer2.0.downsample.1.weight
# fcn.resnet34_8s.layer2.0.downsample.1.bias
# fcn.resnet34_8s.layer2.0.downsample.1.running_mean
# fcn.resnet34_8s.layer2.0.downsample.1.running_var
# fcn.resnet34_8s.layer2.0.downsample.1.num_batches_tracked
# fcn.resnet34_8s.layer2.1.conv1.weight
# fcn.resnet34_8s.layer2.1.bn1.weight
# fcn.resnet34_8s.layer2.1.bn1.bias
# fcn.resnet34_8s.layer2.1.bn1.running_mean
# fcn.resnet34_8s.layer2.1.bn1.running_var
# fcn.resnet34_8s.layer2.1.bn1.num_batches_tracked
# fcn.resnet34_8s.layer2.1.conv2.weight
# fcn.resnet34_8s.layer2.1.bn2.weight
# fcn.resnet34_8s.layer2.1.bn2.bias
# fcn.resnet34_8s.layer2.1.bn2.running_mean
# fcn.resnet34_8s.layer2.1.bn2.running_var
# fcn.resnet34_8s.layer2.1.bn2.num_batches_tracked
# fcn.resnet34_8s.layer2.2.conv1.weight
# fcn.resnet34_8s.layer2.2.bn1.weight
# fcn.resnet34_8s.layer2.2.bn1.bias
# fcn.resnet34_8s.layer2.2.bn1.running_mean
# fcn.resnet34_8s.layer2.2.bn1.running_var
# fcn.resnet34_8s.layer2.2.bn1.num_batches_tracked
# fcn.resnet34_8s.layer2.2.conv2.weight
# fcn.resnet34_8s.layer2.2.bn2.weight
# fcn.resnet34_8s.layer2.2.bn2.bias
# fcn.resnet34_8s.layer2.2.bn2.running_mean
# fcn.resnet34_8s.layer2.2.bn2.running_var
# fcn.resnet34_8s.layer2.2.bn2.num_batches_tracked
# fcn.resnet34_8s.layer2.3.conv1.weight
# fcn.resnet34_8s.layer2.3.bn1.weight
# fcn.resnet34_8s.layer2.3.bn1.bias
# fcn.resnet34_8s.layer2.3.bn1.running_mean
# fcn.resnet34_8s.layer2.3.bn1.running_var
# fcn.resnet34_8s.layer2.3.bn1.num_batches_tracked
# fcn.resnet34_8s.layer2.3.conv2.weight
# fcn.resnet34_8s.layer2.3.bn2.weight
# fcn.resnet34_8s.layer2.3.bn2.bias
# fcn.resnet34_8s.layer2.3.bn2.running_mean
# fcn.resnet34_8s.layer2.3.bn2.running_var
# fcn.resnet34_8s.layer2.3.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.0.conv1.weight
# fcn.resnet34_8s.layer3.0.bn1.weight
# fcn.resnet34_8s.layer3.0.bn1.bias
# fcn.resnet34_8s.layer3.0.bn1.running_mean
# fcn.resnet34_8s.layer3.0.bn1.running_var
# fcn.resnet34_8s.layer3.0.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.0.conv2.weight
# fcn.resnet34_8s.layer3.0.bn2.weight
# fcn.resnet34_8s.layer3.0.bn2.bias
# fcn.resnet34_8s.layer3.0.bn2.running_mean
# fcn.resnet34_8s.layer3.0.bn2.running_var
# fcn.resnet34_8s.layer3.0.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.0.downsample.0.weight
# fcn.resnet34_8s.layer3.0.downsample.1.weight
# fcn.resnet34_8s.layer3.0.downsample.1.bias
# fcn.resnet34_8s.layer3.0.downsample.1.running_mean
# fcn.resnet34_8s.layer3.0.downsample.1.running_var
# fcn.resnet34_8s.layer3.0.downsample.1.num_batches_tracked
# fcn.resnet34_8s.layer3.1.conv1.weight
# fcn.resnet34_8s.layer3.1.bn1.weight
# fcn.resnet34_8s.layer3.1.bn1.bias
# fcn.resnet34_8s.layer3.1.bn1.running_mean
# fcn.resnet34_8s.layer3.1.bn1.running_var
# fcn.resnet34_8s.layer3.1.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.1.conv2.weight
# fcn.resnet34_8s.layer3.1.bn2.weight
# fcn.resnet34_8s.layer3.1.bn2.bias
# fcn.resnet34_8s.layer3.1.bn2.running_mean
# fcn.resnet34_8s.layer3.1.bn2.running_var
# fcn.resnet34_8s.layer3.1.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.2.conv1.weight
# fcn.resnet34_8s.layer3.2.bn1.weight
# fcn.resnet34_8s.layer3.2.bn1.bias
# fcn.resnet34_8s.layer3.2.bn1.running_mean
# fcn.resnet34_8s.layer3.2.bn1.running_var
# fcn.resnet34_8s.layer3.2.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.2.conv2.weight
# fcn.resnet34_8s.layer3.2.bn2.weight
# fcn.resnet34_8s.layer3.2.bn2.bias
# fcn.resnet34_8s.layer3.2.bn2.running_mean
# fcn.resnet34_8s.layer3.2.bn2.running_var
# fcn.resnet34_8s.layer3.2.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.3.conv1.weight
# fcn.resnet34_8s.layer3.3.bn1.weight
# fcn.resnet34_8s.layer3.3.bn1.bias
# fcn.resnet34_8s.layer3.3.bn1.running_mean
# fcn.resnet34_8s.layer3.3.bn1.running_var
# fcn.resnet34_8s.layer3.3.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.3.conv2.weight
# fcn.resnet34_8s.layer3.3.bn2.weight
# fcn.resnet34_8s.layer3.3.bn2.bias
# fcn.resnet34_8s.layer3.3.bn2.running_mean
# fcn.resnet34_8s.layer3.3.bn2.running_var
# fcn.resnet34_8s.layer3.3.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.4.conv1.weight
# fcn.resnet34_8s.layer3.4.bn1.weight
# fcn.resnet34_8s.layer3.4.bn1.bias
# fcn.resnet34_8s.layer3.4.bn1.running_mean
# fcn.resnet34_8s.layer3.4.bn1.running_var
# fcn.resnet34_8s.layer3.4.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.4.conv2.weight
# fcn.resnet34_8s.layer3.4.bn2.weight
# fcn.resnet34_8s.layer3.4.bn2.bias
# fcn.resnet34_8s.layer3.4.bn2.running_mean
# fcn.resnet34_8s.layer3.4.bn2.running_var
# fcn.resnet34_8s.layer3.4.bn2.num_batches_tracked
# fcn.resnet34_8s.layer3.5.conv1.weight
# fcn.resnet34_8s.layer3.5.bn1.weight
# fcn.resnet34_8s.layer3.5.bn1.bias
# fcn.resnet34_8s.layer3.5.bn1.running_mean
# fcn.resnet34_8s.layer3.5.bn1.running_var
# fcn.resnet34_8s.layer3.5.bn1.num_batches_tracked
# fcn.resnet34_8s.layer3.5.conv2.weight
# fcn.resnet34_8s.layer3.5.bn2.weight
# fcn.resnet34_8s.layer3.5.bn2.bias
# fcn.resnet34_8s.layer3.5.bn2.running_mean
# fcn.resnet34_8s.layer3.5.bn2.running_var
# fcn.resnet34_8s.layer3.5.bn2.num_batches_tracked
# fcn.resnet34_8s.layer4.0.conv1.weight
# fcn.resnet34_8s.layer4.0.bn1.weight
# fcn.resnet34_8s.layer4.0.bn1.bias
# fcn.resnet34_8s.layer4.0.bn1.running_mean
# fcn.resnet34_8s.layer4.0.bn1.running_var
# fcn.resnet34_8s.layer4.0.bn1.num_batches_tracked
# fcn.resnet34_8s.layer4.0.conv2.weight
# fcn.resnet34_8s.layer4.0.bn2.weight
# fcn.resnet34_8s.layer4.0.bn2.bias
# fcn.resnet34_8s.layer4.0.bn2.running_mean
# fcn.resnet34_8s.layer4.0.bn2.running_var
# fcn.resnet34_8s.layer4.0.bn2.num_batches_tracked
# fcn.resnet34_8s.layer4.0.downsample.0.weight
# fcn.resnet34_8s.layer4.0.downsample.1.weight
# fcn.resnet34_8s.layer4.0.downsample.1.bias
# fcn.resnet34_8s.layer4.0.downsample.1.running_mean
# fcn.resnet34_8s.layer4.0.downsample.1.running_var
# fcn.resnet34_8s.layer4.0.downsample.1.num_batches_tracked
# fcn.resnet34_8s.layer4.1.conv1.weight
# fcn.resnet34_8s.layer4.1.bn1.weight
# fcn.resnet34_8s.layer4.1.bn1.bias
# fcn.resnet34_8s.layer4.1.bn1.running_mean
# fcn.resnet34_8s.layer4.1.bn1.running_var
# fcn.resnet34_8s.layer4.1.bn1.num_batches_tracked
# fcn.resnet34_8s.layer4.1.conv2.weight
# fcn.resnet34_8s.layer4.1.bn2.weight
# fcn.resnet34_8s.layer4.1.bn2.bias
# fcn.resnet34_8s.layer4.1.bn2.running_mean
# fcn.resnet34_8s.layer4.1.bn2.running_var
# fcn.resnet34_8s.layer4.1.bn2.num_batches_tracked
# fcn.resnet34_8s.layer4.2.conv1.weight
# fcn.resnet34_8s.layer4.2.bn1.weight
# fcn.resnet34_8s.layer4.2.bn1.bias
# fcn.resnet34_8s.layer4.2.bn1.running_mean
# fcn.resnet34_8s.layer4.2.bn1.running_var
# fcn.resnet34_8s.layer4.2.bn1.num_batches_tracked
# fcn.resnet34_8s.layer4.2.conv2.weight
# fcn.resnet34_8s.layer4.2.bn2.weight
# fcn.resnet34_8s.layer4.2.bn2.bias
# fcn.resnet34_8s.layer4.2.bn2.running_mean
# fcn.resnet34_8s.layer4.2.bn2.running_var
# fcn.resnet34_8s.layer4.2.bn2.num_batches_tracked
# fcn.resnet34_8s.fc.weight
# fcn.resnet34_8s.fc.bias
# fcn_depth.resnet34_8s.conv1.weight
# fcn_depth.resnet34_8s.bn1.weight
# fcn_depth.resnet34_8s.bn1.bias
# fcn_depth.resnet34_8s.bn1.running_mean
# fcn_depth.resnet34_8s.bn1.running_var
# fcn_depth.resnet34_8s.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.0.conv1.weight
# fcn_depth.resnet34_8s.layer1.0.bn1.weight
# fcn_depth.resnet34_8s.layer1.0.bn1.bias
# fcn_depth.resnet34_8s.layer1.0.bn1.running_mean
# fcn_depth.resnet34_8s.layer1.0.bn1.running_var
# fcn_depth.resnet34_8s.layer1.0.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.0.conv2.weight
# fcn_depth.resnet34_8s.layer1.0.bn2.weight
# fcn_depth.resnet34_8s.layer1.0.bn2.bias
# fcn_depth.resnet34_8s.layer1.0.bn2.running_mean
# fcn_depth.resnet34_8s.layer1.0.bn2.running_var
# fcn_depth.resnet34_8s.layer1.0.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.1.conv1.weight
# fcn_depth.resnet34_8s.layer1.1.bn1.weight
# fcn_depth.resnet34_8s.layer1.1.bn1.bias
# fcn_depth.resnet34_8s.layer1.1.bn1.running_mean
# fcn_depth.resnet34_8s.layer1.1.bn1.running_var
# fcn_depth.resnet34_8s.layer1.1.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.1.conv2.weight
# fcn_depth.resnet34_8s.layer1.1.bn2.weight
# fcn_depth.resnet34_8s.layer1.1.bn2.bias
# fcn_depth.resnet34_8s.layer1.1.bn2.running_mean
# fcn_depth.resnet34_8s.layer1.1.bn2.running_var
# fcn_depth.resnet34_8s.layer1.1.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.2.conv1.weight
# fcn_depth.resnet34_8s.layer1.2.bn1.weight
# fcn_depth.resnet34_8s.layer1.2.bn1.bias
# fcn_depth.resnet34_8s.layer1.2.bn1.running_mean
# fcn_depth.resnet34_8s.layer1.2.bn1.running_var
# fcn_depth.resnet34_8s.layer1.2.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer1.2.conv2.weight
# fcn_depth.resnet34_8s.layer1.2.bn2.weight
# fcn_depth.resnet34_8s.layer1.2.bn2.bias
# fcn_depth.resnet34_8s.layer1.2.bn2.running_mean
# fcn_depth.resnet34_8s.layer1.2.bn2.running_var
# fcn_depth.resnet34_8s.layer1.2.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.0.conv1.weight
# fcn_depth.resnet34_8s.layer2.0.bn1.weight
# fcn_depth.resnet34_8s.layer2.0.bn1.bias
# fcn_depth.resnet34_8s.layer2.0.bn1.running_mean
# fcn_depth.resnet34_8s.layer2.0.bn1.running_var
# fcn_depth.resnet34_8s.layer2.0.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.0.conv2.weight
# fcn_depth.resnet34_8s.layer2.0.bn2.weight
# fcn_depth.resnet34_8s.layer2.0.bn2.bias
# fcn_depth.resnet34_8s.layer2.0.bn2.running_mean
# fcn_depth.resnet34_8s.layer2.0.bn2.running_var
# fcn_depth.resnet34_8s.layer2.0.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.0.downsample.0.weight
# fcn_depth.resnet34_8s.layer2.0.downsample.1.weight
# fcn_depth.resnet34_8s.layer2.0.downsample.1.bias
# fcn_depth.resnet34_8s.layer2.0.downsample.1.running_mean
# fcn_depth.resnet34_8s.layer2.0.downsample.1.running_var
# fcn_depth.resnet34_8s.layer2.0.downsample.1.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.1.conv1.weight
# fcn_depth.resnet34_8s.layer2.1.bn1.weight
# fcn_depth.resnet34_8s.layer2.1.bn1.bias
# fcn_depth.resnet34_8s.layer2.1.bn1.running_mean
# fcn_depth.resnet34_8s.layer2.1.bn1.running_var
# fcn_depth.resnet34_8s.layer2.1.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.1.conv2.weight
# fcn_depth.resnet34_8s.layer2.1.bn2.weight
# fcn_depth.resnet34_8s.layer2.1.bn2.bias
# fcn_depth.resnet34_8s.layer2.1.bn2.running_mean
# fcn_depth.resnet34_8s.layer2.1.bn2.running_var
# fcn_depth.resnet34_8s.layer2.1.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.2.conv1.weight
# fcn_depth.resnet34_8s.layer2.2.bn1.weight
# fcn_depth.resnet34_8s.layer2.2.bn1.bias
# fcn_depth.resnet34_8s.layer2.2.bn1.running_mean
# fcn_depth.resnet34_8s.layer2.2.bn1.running_var
# fcn_depth.resnet34_8s.layer2.2.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.2.conv2.weight
# fcn_depth.resnet34_8s.layer2.2.bn2.weight
# fcn_depth.resnet34_8s.layer2.2.bn2.bias
# fcn_depth.resnet34_8s.layer2.2.bn2.running_mean
# fcn_depth.resnet34_8s.layer2.2.bn2.running_var
# fcn_depth.resnet34_8s.layer2.2.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.3.conv1.weight
# fcn_depth.resnet34_8s.layer2.3.bn1.weight
# fcn_depth.resnet34_8s.layer2.3.bn1.bias
# fcn_depth.resnet34_8s.layer2.3.bn1.running_mean
# fcn_depth.resnet34_8s.layer2.3.bn1.running_var
# fcn_depth.resnet34_8s.layer2.3.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer2.3.conv2.weight
# fcn_depth.resnet34_8s.layer2.3.bn2.weight
# fcn_depth.resnet34_8s.layer2.3.bn2.bias
# fcn_depth.resnet34_8s.layer2.3.bn2.running_mean
# fcn_depth.resnet34_8s.layer2.3.bn2.running_var
# fcn_depth.resnet34_8s.layer2.3.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.0.conv1.weight
# fcn_depth.resnet34_8s.layer3.0.bn1.weight
# fcn_depth.resnet34_8s.layer3.0.bn1.bias
# fcn_depth.resnet34_8s.layer3.0.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.0.bn1.running_var
# fcn_depth.resnet34_8s.layer3.0.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.0.conv2.weight
# fcn_depth.resnet34_8s.layer3.0.bn2.weight
# fcn_depth.resnet34_8s.layer3.0.bn2.bias
# fcn_depth.resnet34_8s.layer3.0.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.0.bn2.running_var
# fcn_depth.resnet34_8s.layer3.0.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.0.downsample.0.weight
# fcn_depth.resnet34_8s.layer3.0.downsample.1.weight
# fcn_depth.resnet34_8s.layer3.0.downsample.1.bias
# fcn_depth.resnet34_8s.layer3.0.downsample.1.running_mean
# fcn_depth.resnet34_8s.layer3.0.downsample.1.running_var
# fcn_depth.resnet34_8s.layer3.0.downsample.1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.1.conv1.weight
# fcn_depth.resnet34_8s.layer3.1.bn1.weight
# fcn_depth.resnet34_8s.layer3.1.bn1.bias
# fcn_depth.resnet34_8s.layer3.1.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.1.bn1.running_var
# fcn_depth.resnet34_8s.layer3.1.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.1.conv2.weight
# fcn_depth.resnet34_8s.layer3.1.bn2.weight
# fcn_depth.resnet34_8s.layer3.1.bn2.bias
# fcn_depth.resnet34_8s.layer3.1.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.1.bn2.running_var
# fcn_depth.resnet34_8s.layer3.1.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.2.conv1.weight
# fcn_depth.resnet34_8s.layer3.2.bn1.weight
# fcn_depth.resnet34_8s.layer3.2.bn1.bias
# fcn_depth.resnet34_8s.layer3.2.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.2.bn1.running_var
# fcn_depth.resnet34_8s.layer3.2.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.2.conv2.weight
# fcn_depth.resnet34_8s.layer3.2.bn2.weight
# fcn_depth.resnet34_8s.layer3.2.bn2.bias
# fcn_depth.resnet34_8s.layer3.2.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.2.bn2.running_var
# fcn_depth.resnet34_8s.layer3.2.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.3.conv1.weight
# fcn_depth.resnet34_8s.layer3.3.bn1.weight
# fcn_depth.resnet34_8s.layer3.3.bn1.bias
# fcn_depth.resnet34_8s.layer3.3.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.3.bn1.running_var
# fcn_depth.resnet34_8s.layer3.3.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.3.conv2.weight
# fcn_depth.resnet34_8s.layer3.3.bn2.weight
# fcn_depth.resnet34_8s.layer3.3.bn2.bias
# fcn_depth.resnet34_8s.layer3.3.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.3.bn2.running_var
# fcn_depth.resnet34_8s.layer3.3.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.4.conv1.weight
# fcn_depth.resnet34_8s.layer3.4.bn1.weight
# fcn_depth.resnet34_8s.layer3.4.bn1.bias
# fcn_depth.resnet34_8s.layer3.4.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.4.bn1.running_var
# fcn_depth.resnet34_8s.layer3.4.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.4.conv2.weight
# fcn_depth.resnet34_8s.layer3.4.bn2.weight
# fcn_depth.resnet34_8s.layer3.4.bn2.bias
# fcn_depth.resnet34_8s.layer3.4.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.4.bn2.running_var
# fcn_depth.resnet34_8s.layer3.4.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.5.conv1.weight
# fcn_depth.resnet34_8s.layer3.5.bn1.weight
# fcn_depth.resnet34_8s.layer3.5.bn1.bias
# fcn_depth.resnet34_8s.layer3.5.bn1.running_mean
# fcn_depth.resnet34_8s.layer3.5.bn1.running_var
# fcn_depth.resnet34_8s.layer3.5.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer3.5.conv2.weight
# fcn_depth.resnet34_8s.layer3.5.bn2.weight
# fcn_depth.resnet34_8s.layer3.5.bn2.bias
# fcn_depth.resnet34_8s.layer3.5.bn2.running_mean
# fcn_depth.resnet34_8s.layer3.5.bn2.running_var
# fcn_depth.resnet34_8s.layer3.5.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.0.conv1.weight
# fcn_depth.resnet34_8s.layer4.0.bn1.weight
# fcn_depth.resnet34_8s.layer4.0.bn1.bias
# fcn_depth.resnet34_8s.layer4.0.bn1.running_mean
# fcn_depth.resnet34_8s.layer4.0.bn1.running_var
# fcn_depth.resnet34_8s.layer4.0.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.0.conv2.weight
# fcn_depth.resnet34_8s.layer4.0.bn2.weight
# fcn_depth.resnet34_8s.layer4.0.bn2.bias
# fcn_depth.resnet34_8s.layer4.0.bn2.running_mean
# fcn_depth.resnet34_8s.layer4.0.bn2.running_var
# fcn_depth.resnet34_8s.layer4.0.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.0.downsample.0.weight
# fcn_depth.resnet34_8s.layer4.0.downsample.1.weight
# fcn_depth.resnet34_8s.layer4.0.downsample.1.bias
# fcn_depth.resnet34_8s.layer4.0.downsample.1.running_mean
# fcn_depth.resnet34_8s.layer4.0.downsample.1.running_var
# fcn_depth.resnet34_8s.layer4.0.downsample.1.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.1.conv1.weight
# fcn_depth.resnet34_8s.layer4.1.bn1.weight
# fcn_depth.resnet34_8s.layer4.1.bn1.bias
# fcn_depth.resnet34_8s.layer4.1.bn1.running_mean
# fcn_depth.resnet34_8s.layer4.1.bn1.running_var
# fcn_depth.resnet34_8s.layer4.1.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.1.conv2.weight
# fcn_depth.resnet34_8s.layer4.1.bn2.weight
# fcn_depth.resnet34_8s.layer4.1.bn2.bias
# fcn_depth.resnet34_8s.layer4.1.bn2.running_mean
# fcn_depth.resnet34_8s.layer4.1.bn2.running_var
# fcn_depth.resnet34_8s.layer4.1.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.2.conv1.weight
# fcn_depth.resnet34_8s.layer4.2.bn1.weight
# fcn_depth.resnet34_8s.layer4.2.bn1.bias
# fcn_depth.resnet34_8s.layer4.2.bn1.running_mean
# fcn_depth.resnet34_8s.layer4.2.bn1.running_var
# fcn_depth.resnet34_8s.layer4.2.bn1.num_batches_tracked
# fcn_depth.resnet34_8s.layer4.2.conv2.weight
# fcn_depth.resnet34_8s.layer4.2.bn2.weight
# fcn_depth.resnet34_8s.layer4.2.bn2.bias
# fcn_depth.resnet34_8s.layer4.2.bn2.running_mean
# fcn_depth.resnet34_8s.layer4.2.bn2.running_var
# fcn_depth.resnet34_8s.layer4.2.bn2.num_batches_tracked
# fcn_depth.resnet34_8s.fc.weight
# fcn_depth.resnet34_8s.fc.bias
# =================================================
# => setting adam solver
# /home/thomas/anaconda3/envs/uois3d/lib/python3.7/site-packages/torch/nn/functional.py:3104: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# [0/24][0/313], loss 1.7054, loss intra: 0.0697, loss_inter 1.6357, lr 0.000010, time 1.42
# [0/24][1/313], loss 1.5634, loss intra: 0.0721, loss_inter 1.4913, lr 0.000010, time 0.52
# [0/24][2/313], loss 1.5267, loss intra: 0.0712, loss_inter 1.4555, lr 0.000010, time 0.53
# [0/24][3/313], loss 1.5166, loss intra: 0.0794, loss_inter 1.4372, lr 0.000010, time 0.54
# [0/24][4/313], loss 1.4093, loss intra: 0.0800, loss_inter 1.3293, lr 0.000010, time 0.53
# [0/24][5/313], loss 1.6902, loss intra: 0.1000, loss_inter 1.5902, lr 0.000010, time 0.52
# [0/24][6/313], loss 0.8567, loss intra: 0.0884, loss_inter 0.7683, lr 0.000010, time 0.53
# [0/24][7/313], loss 0.6959, loss intra: 0.0854, loss_inter 0.6105, lr 0.000010, time 0.54
# [0/24][8/313], loss 0.6087, loss intra: 0.0871, loss_inter 0.5216, lr 0.000010, time 0.54
# [0/24][9/313], loss 1.2958, loss intra: 0.1187, loss_inter 1.1771, lr 0.000010, time 0.54
# [0/24][10/313], loss 1.0485, loss intra: 0.1166, loss_inter 0.9319, lr 0.000010, time 0.54
# [0/24][11/313], loss 0.7154, loss intra: 0.1255, loss_inter 0.5899, lr 0.000010, time 0.54
# [0/24][12/313], loss 0.4092, loss intra: 0.0890, loss_inter 0.3202, lr 0.000010, time 0.54
# [0/24][13/313], loss 0.4943, loss intra: 0.1216, loss_inter 0.3728, lr 0.000010, time 0.54
# [0/24][14/313], loss 0.7249, loss intra: 0.1311, loss_inter 0.5938, lr 0.000010, time 0.54
# [0/24][15/313], loss 0.6157, loss intra: 0.1237, loss_inter 0.4920, lr 0.000010, time 0.54
# [0/24][16/313], loss 0.3615, loss intra: 0.1483, loss_inter 0.2132, lr 0.000010, time 0.53
# [0/24][17/313], loss 0.4973, loss intra: 0.1389, loss_inter 0.3584, lr 0.000010, time 0.53
# [0/24][18/313], loss 0.5400, loss intra: 0.1677, loss_inter 0.3723, lr 0.000010, time 0.54
# [0/24][19/313], loss 0.3939, loss intra: 0.1408, loss_inter 0.2531, lr 0.000010, time 0.55
# [0/24][20/313], loss 0.3946, loss intra: 0.1295, loss_inter 0.2652, lr 0.000010, time 0.55
# [0/24][21/313], loss 0.5514, loss intra: 0.1573, loss_inter 0.3941, lr 0.000010, time 0.55
# [0/24][22/313], loss 0.3358, loss intra: 0.1405, loss_inter 0.1953, lr 0.000010, time 0.55
# [0/24][23/313], loss 0.2997, loss intra: 0.1370, loss_inter 0.1627, lr 0.000010, time 0.56
# [0/24][24/313], loss 0.3233, loss intra: 0.1452, loss_inter 0.1781, lr 0.000010, time 0.55
# [0/24][25/313], loss 0.3842, loss intra: 0.1692, loss_inter 0.2151, lr 0.000010, time 0.54
# [0/24][26/313], loss 0.3542, loss intra: 0.1777, loss_inter 0.1765, lr 0.000010, time 0.54
# [0/24][27/313], loss 0.4044, loss intra: 0.1553, loss_inter 0.2491, lr 0.000010, time 0.55
# [0/24][28/313], loss 0.4378, loss intra: 0.1851, loss_inter 0.2527, lr 0.000010, time 0.54
# [0/24][29/313], loss 0.3966, loss intra: 0.1507, loss_inter 0.2459, lr 0.000010, time 0.55
# [0/24][30/313], loss 0.3228, loss intra: 0.1461, loss_inter 0.1767, lr 0.000010, time 0.55
# [0/24][31/313], loss 0.3806, loss intra: 0.1511, loss_inter 0.2296, lr 0.000010, time 0.55
# [0/24][32/313], loss 0.2917, loss intra: 0.1670, loss_inter 0.1247, lr 0.000010, time 0.54
# [0/24][33/313], loss 0.3446, loss intra: 0.1944, loss_inter 0.1503, lr 0.000010, time 0.55
# [0/24][34/313], loss 0.3107, loss intra: 0.1523, loss_inter 0.1584, lr 0.000010, time 0.55
# [0/24][35/313], loss 0.3225, loss intra: 0.1876, loss_inter 0.1348, lr 0.000010, time 0.56
# [0/24][36/313], loss 0.3008, loss intra: 0.1816, loss_inter 0.1192, lr 0.000010, time 0.54
# [0/24][37/313], loss 0.4231, loss intra: 0.1959, loss_inter 0.2272, lr 0.000010, time 0.54
# [0/24][38/313], loss 0.3050, loss intra: 0.1556, loss_inter 0.1494, lr 0.000010, time 0.55
# [0/24][39/313], loss 0.2973, loss intra: 0.2246, loss_inter 0.0728, lr 0.000010, time 0.53
# [0/24][40/313], loss 0.3688, loss intra: 0.1926, loss_inter 0.1762, lr 0.000010, time 0.54
# [0/24][41/313], loss 0.3160, loss intra: 0.1906, loss_inter 0.1255, lr 0.000010, time 0.54
# [0/24][42/313], loss 0.3297, loss intra: 0.1577, loss_inter 0.1721, lr 0.000010, time 0.55
# [0/24][43/313], loss 0.2461, loss intra: 0.1572, loss_inter 0.0888, lr 0.000010, time 0.55
# [0/24][44/313], loss 0.2442, loss intra: 0.1356, loss_inter 0.1085, lr 0.000010, time 0.56
# [0/24][45/313], loss 0.3710, loss intra: 0.1835, loss_inter 0.1875, lr 0.000010, time 0.54
# [0/24][46/313], loss 0.2727, loss intra: 0.1844, loss_inter 0.0883, lr 0.000010, time 0.55
# [0/24][47/313], loss 0.3510, loss intra: 0.1696, loss_inter 0.1814, lr 0.000010, time 0.54
# [0/24][48/313], loss 0.3167, loss intra: 0.1591, loss_inter 0.1576, lr 0.000010, time 0.55
# [0/24][49/313], loss 0.2971, loss intra: 0.1736, loss_inter 0.1235, lr 0.000010, time 0.55
# [0/24][50/313], loss 0.3384, loss intra: 0.1865, loss_inter 0.1519, lr 0.000010, time 0.54
# [0/24][51/313], loss 0.2294, loss intra: 0.1465, loss_inter 0.0829, lr 0.000010, time 0.56
# [0/24][52/313], loss 0.2414, loss intra: 0.1490, loss_inter 0.0924, lr 0.000010, time 0.55
# [0/24][53/313], loss 0.2894, loss intra: 0.1532, loss_inter 0.1362, lr 0.000010, time 0.55
# [0/24][54/313], loss 0.2072, loss intra: 0.1762, loss_inter 0.0311, lr 0.000010, time 0.55
# [0/24][55/313], loss 0.2422, loss intra: 0.1480, loss_inter 0.0942, lr 0.000010, time 0.55
# [0/24][56/313], loss 0.3254, loss intra: 0.1646, loss_inter 0.1608, lr 0.000010, time 0.55
# [0/24][57/313], loss 0.3532, loss intra: 0.1732, loss_inter 0.1800, lr 0.000010, time 0.55
# [0/24][58/313], loss 0.2887, loss intra: 0.1735, loss_inter 0.1153, lr 0.000010, time 0.55
# [0/24][59/313], loss 0.2892, loss intra: 0.1683, loss_inter 0.1209, lr 0.000010, time 0.54
# [0/24][60/313], loss 0.2441, loss intra: 0.1608, loss_inter 0.0833, lr 0.000010, time 0.55
# [0/24][61/313], loss 0.2991, loss intra: 0.1841, loss_inter 0.1149, lr 0.000010, time 0.55
# [0/24][62/313], loss 0.3005, loss intra: 0.1679, loss_inter 0.1326, lr 0.000010, time 0.55
# [0/24][63/313], loss 0.2433, loss intra: 0.1458, loss_inter 0.0974, lr 0.000010, time 0.56
# [0/24][64/313], loss 0.2714, loss intra: 0.1740, loss_inter 0.0974, lr 0.000010, time 0.55
# [0/24][65/313], loss 0.2551, loss intra: 0.1733, loss_inter 0.0818, lr 0.000010, time 0.55
# [0/24][66/313], loss 0.3277, loss intra: 0.1781, loss_inter 0.1496, lr 0.000010, time 0.55
# [0/24][67/313], loss 0.2390, loss intra: 0.1476, loss_inter 0.0914, lr 0.000010, time 0.56
# [0/24][68/313], loss 0.2528, loss intra: 0.1600, loss_inter 0.0928, lr 0.000010, time 0.56
# [0/24][69/313], loss 0.3162, loss intra: 0.1371, loss_inter 0.1790, lr 0.000010, time 0.57
# [0/24][70/313], loss 0.2300, loss intra: 0.1654, loss_inter 0.0646, lr 0.000010, time 0.55
# [0/24][71/313], loss 0.2280, loss intra: 0.1361, loss_inter 0.0919, lr 0.000010, time 0.55
# [0/24][72/313], loss 0.2535, loss intra: 0.1408, loss_inter 0.1126, lr 0.000010, time 0.55
# [0/24][73/313], loss 0.2397, loss intra: 0.2053, loss_inter 0.0344, lr 0.000010, time 0.53
# [0/24][74/313], loss 0.2295, loss intra: 0.1456, loss_inter 0.0840, lr 0.000010, time 0.55
# ...
# [23/24][142/313], loss 0.0617, loss intra: 0.0521, loss_inter 0.0096, lr 0.000010, time 0.61
# [23/24][143/313], loss 0.0592, loss intra: 0.0509, loss_inter 0.0083, lr 0.000010, time 0.60
# [23/24][144/313], loss 0.0631, loss intra: 0.0532, loss_inter 0.0099, lr 0.000010, time 0.60
# [23/24][145/313], loss 0.0698, loss intra: 0.0639, loss_inter 0.0058, lr 0.000010, time 0.60
# [23/24][146/313], loss 0.0733, loss intra: 0.0644, loss_inter 0.0088, lr 0.000010, time 0.60
# [23/24][147/313], loss 0.0608, loss intra: 0.0564, loss_inter 0.0043, lr 0.000010, time 0.61
# [23/24][148/313], loss 0.0669, loss intra: 0.0602, loss_inter 0.0066, lr 0.000010, time 0.60
# [23/24][149/313], loss 0.0818, loss intra: 0.0672, loss_inter 0.0146, lr 0.000010, time 0.60
# [23/24][150/313], loss 0.0573, loss intra: 0.0496, loss_inter 0.0077, lr 0.000010, time 0.60
# [23/24][151/313], loss 0.0712, loss intra: 0.0522, loss_inter 0.0190, lr 0.000010, time 0.60
# [23/24][152/313], loss 0.0642, loss intra: 0.0550, loss_inter 0.0092, lr 0.000010, time 0.60
# [23/24][153/313], loss 0.0605, loss intra: 0.0559, loss_inter 0.0046, lr 0.000010, time 0.60
# [23/24][154/313], loss 0.0770, loss intra: 0.0676, loss_inter 0.0095, lr 0.000010, time 0.59
# [23/24][155/313], loss 0.0748, loss intra: 0.0668, loss_inter 0.0080, lr 0.000010, time 0.60
# [23/24][156/313], loss 0.0581, loss intra: 0.0520, loss_inter 0.0062, lr 0.000010, time 0.61
# [23/24][157/313], loss 0.0755, loss intra: 0.0507, loss_inter 0.0247, lr 0.000010, time 0.60
# [23/24][158/313], loss 0.0691, loss intra: 0.0640, loss_inter 0.0051, lr 0.000010, time 0.57
# [23/24][159/313], loss 0.0566, loss intra: 0.0521, loss_inter 0.0044, lr 0.000010, time 0.60
# [23/24][160/313], loss 0.0714, loss intra: 0.0616, loss_inter 0.0098, lr 0.000010, time 0.60
# [23/24][161/313], loss 0.0794, loss intra: 0.0675, loss_inter 0.0119, lr 0.000010, time 0.60
# [23/24][162/313], loss 0.0820, loss intra: 0.0734, loss_inter 0.0087, lr 0.000010, time 0.60
# [23/24][163/313], loss 0.0570, loss intra: 0.0500, loss_inter 0.0070, lr 0.000010, time 0.61
# [23/24][164/313], loss 0.0705, loss intra: 0.0628, loss_inter 0.0076, lr 0.000010, time 0.60
# [23/24][165/313], loss 0.0581, loss intra: 0.0504, loss_inter 0.0077, lr 0.000010, time 0.61
# [23/24][166/313], loss 0.0660, loss intra: 0.0560, loss_inter 0.0101, lr 0.000010, time 0.61
# [23/24][167/313], loss 0.0747, loss intra: 0.0657, loss_inter 0.0090, lr 0.000010, time 0.60
# [23/24][168/313], loss 0.0788, loss intra: 0.0681, loss_inter 0.0106, lr 0.000010, time 0.60
# [23/24][169/313], loss 0.0552, loss intra: 0.0517, loss_inter 0.0036, lr 0.000010, time 0.61
# [23/24][170/313], loss 0.0658, loss intra: 0.0576, loss_inter 0.0082, lr 0.000010, time 0.61
# [23/24][171/313], loss 0.0576, loss intra: 0.0514, loss_inter 0.0062, lr 0.000010, time 0.60
# [23/24][172/313], loss 0.1000, loss intra: 0.0740, loss_inter 0.0261, lr 0.000010, time 0.60
# [23/24][173/313], loss 0.0725, loss intra: 0.0652, loss_inter 0.0073, lr 0.000010, time 0.60
# [23/24][174/313], loss 0.0791, loss intra: 0.0546, loss_inter 0.0244, lr 0.000010, time 0.61
# [23/24][175/313], loss 0.0994, loss intra: 0.0611, loss_inter 0.0383, lr 0.000010, time 0.60
# [23/24][176/313], loss 0.0733, loss intra: 0.0655, loss_inter 0.0078, lr 0.000010, time 0.60
# [23/24][177/313], loss 0.0779, loss intra: 0.0702, loss_inter 0.0077, lr 0.000010, time 0.59
# [23/24][178/313], loss 0.0726, loss intra: 0.0657, loss_inter 0.0068, lr 0.000010, time 0.59
# [23/24][179/313], loss 0.0661, loss intra: 0.0618, loss_inter 0.0044, lr 0.000010, time 0.60
# [23/24][180/313], loss 0.0581, loss intra: 0.0544, loss_inter 0.0037, lr 0.000010, time 0.61
# [23/24][181/313], loss 0.0663, loss intra: 0.0580, loss_inter 0.0083, lr 0.000010, time 0.60
# [23/24][182/313], loss 0.0598, loss intra: 0.0537, loss_inter 0.0062, lr 0.000010, time 0.61
# [23/24][183/313], loss 0.0723, loss intra: 0.0669, loss_inter 0.0054, lr 0.000010, time 0.59
# [23/24][184/313], loss 0.0731, loss intra: 0.0653, loss_inter 0.0078, lr 0.000010, time 0.58
# [23/24][185/313], loss 0.0727, loss intra: 0.0631, loss_inter 0.0095, lr 0.000010, time 0.57
# [23/24][186/313], loss 0.0774, loss intra: 0.0667, loss_inter 0.0107, lr 0.000010, time 0.60
# [23/24][187/313], loss 0.0774, loss intra: 0.0591, loss_inter 0.0183, lr 0.000010, time 0.61
# [23/24][188/313], loss 0.0754, loss intra: 0.0661, loss_inter 0.0094, lr 0.000010, time 0.60
# [23/24][189/313], loss 0.1044, loss intra: 0.0712, loss_inter 0.0332, lr 0.000010, time 0.60
# [23/24][190/313], loss 0.0759, loss intra: 0.0603, loss_inter 0.0156, lr 0.000010, time 0.61
# [23/24][191/313], loss 0.0806, loss intra: 0.0717, loss_inter 0.0089, lr 0.000010, time 0.60
# [23/24][192/313], loss 0.0707, loss intra: 0.0674, loss_inter 0.0033, lr 0.000010, time 0.60
# [23/24][193/313], loss 0.0644, loss intra: 0.0601, loss_inter 0.0043, lr 0.000010, time 0.60
# [23/24][194/313], loss 0.0760, loss intra: 0.0686, loss_inter 0.0073, lr 0.000010, time 0.60
# [23/24][195/313], loss 0.0578, loss intra: 0.0511, loss_inter 0.0067, lr 0.000010, time 0.60
# [23/24][196/313], loss 0.0605, loss intra: 0.0495, loss_inter 0.0110, lr 0.000010, time 0.61
# [23/24][197/313], loss 0.0542, loss intra: 0.0481, loss_inter 0.0061, lr 0.000010, time 0.61
# [23/24][198/313], loss 0.0660, loss intra: 0.0510, loss_inter 0.0150, lr 0.000010, time 0.61
# [23/24][199/313], loss 0.0629, loss intra: 0.0541, loss_inter 0.0089, lr 0.000010, time 0.60
# [23/24][200/313], loss 0.0644, loss intra: 0.0552, loss_inter 0.0092, lr 0.000010, time 0.60
# [23/24][201/313], loss 0.0810, loss intra: 0.0521, loss_inter 0.0289, lr 0.000010, time 0.61
# [23/24][202/313], loss 0.0651, loss intra: 0.0517, loss_inter 0.0133, lr 0.000010, time 0.60
# [23/24][203/313], loss 0.1033, loss intra: 0.0599, loss_inter 0.0434, lr 0.000010, time 0.61
# [23/24][204/313], loss 0.0703, loss intra: 0.0577, loss_inter 0.0126, lr 0.000010, time 0.61
# [23/24][205/313], loss 0.0760, loss intra: 0.0552, loss_inter 0.0208, lr 0.000010, time 0.61
# [23/24][206/313], loss 0.0711, loss intra: 0.0619, loss_inter 0.0092, lr 0.000010, time 0.60
# [23/24][207/313], loss 0.0742, loss intra: 0.0686, loss_inter 0.0056, lr 0.000010, time 0.60
# [23/24][208/313], loss 0.0672, loss intra: 0.0569, loss_inter 0.0103, lr 0.000010, time 0.60
# [23/24][209/313], loss 0.0681, loss intra: 0.0640, loss_inter 0.0041, lr 0.000010, time 0.59
# [23/24][210/313], loss 0.0723, loss intra: 0.0612, loss_inter 0.0111, lr 0.000010, time 0.60
# [23/24][211/313], loss 0.0622, loss intra: 0.0534, loss_inter 0.0088, lr 0.000010, time 0.60
# [23/24][212/313], loss 0.0708, loss intra: 0.0619, loss_inter 0.0089, lr 0.000010, time 0.59
# [23/24][213/313], loss 0.0680, loss intra: 0.0576, loss_inter 0.0104, lr 0.000010, time 0.60
# [23/24][214/313], loss 0.0800, loss intra: 0.0709, loss_inter 0.0091, lr 0.000010, time 0.60
# [23/24][215/313], loss 0.0663, loss intra: 0.0613, loss_inter 0.0051, lr 0.000010, time 0.60
# [23/24][216/313], loss 0.0776, loss intra: 0.0612, loss_inter 0.0164, lr 0.000010, time 0.61
# [23/24][217/313], loss 0.1040, loss intra: 0.0668, loss_inter 0.0372, lr 0.000010, time 0.60
# [23/24][218/313], loss 0.0783, loss intra: 0.0680, loss_inter 0.0102, lr 0.000010, time 0.58
# [23/24][219/313], loss 0.0730, loss intra: 0.0679, loss_inter 0.0051, lr 0.000010, time 0.57
# [23/24][220/313], loss 0.0616, loss intra: 0.0578, loss_inter 0.0038, lr 0.000010, time 0.61
# [23/24][221/313], loss 0.1172, loss intra: 0.0708, loss_inter 0.0463, lr 0.000010, time 0.60
# [23/24][222/313], loss 0.0706, loss intra: 0.0572, loss_inter 0.0134, lr 0.000010, time 0.61
# [23/24][223/313], loss 0.0698, loss intra: 0.0634, loss_inter 0.0064, lr 0.000010, time 0.60
# [23/24][224/313], loss 0.0692, loss intra: 0.0578, loss_inter 0.0115, lr 0.000010, time 0.60
# [23/24][225/313], loss 0.0955, loss intra: 0.0785, loss_inter 0.0170, lr 0.000010, time 0.60
# [23/24][226/313], loss 0.0749, loss intra: 0.0661, loss_inter 0.0088, lr 0.000010, time 0.60
# [23/24][227/313], loss 0.0744, loss intra: 0.0682, loss_inter 0.0062, lr 0.000010, time 0.60
# [23/24][228/313], loss 0.0729, loss intra: 0.0646, loss_inter 0.0083, lr 0.000010, time 0.60
# [23/24][229/313], loss 0.0744, loss intra: 0.0581, loss_inter 0.0163, lr 0.000010, time 0.61
# [23/24][230/313], loss 0.0628, loss intra: 0.0537, loss_inter 0.0091, lr 0.000010, time 0.60
# [23/24][231/313], loss 0.0622, loss intra: 0.0569, loss_inter 0.0053, lr 0.000010, time 0.60
# [23/24][232/313], loss 0.0770, loss intra: 0.0581, loss_inter 0.0190, lr 0.000010, time 0.60
# [23/24][233/313], loss 0.0896, loss intra: 0.0644, loss_inter 0.0252, lr 0.000010, time 0.59
# [23/24][234/313], loss 0.0652, loss intra: 0.0584, loss_inter 0.0068, lr 0.000010, time 0.60
# [23/24][235/313], loss 0.0632, loss intra: 0.0557, loss_inter 0.0074, lr 0.000010, time 0.59
# [23/24][236/313], loss 0.0695, loss intra: 0.0678, loss_inter 0.0017, lr 0.000010, time 0.61
# [23/24][237/313], loss 0.0764, loss intra: 0.0715, loss_inter 0.0049, lr 0.000010, time 0.60
# [23/24][238/313], loss 0.0620, loss intra: 0.0585, loss_inter 0.0035, lr 0.000010, time 0.60
# [23/24][239/313], loss 0.0688, loss intra: 0.0618, loss_inter 0.0070, lr 0.000010, time 0.60
# [23/24][240/313], loss 0.0590, loss intra: 0.0563, loss_inter 0.0027, lr 0.000010, time 0.59
# [23/24][241/313], loss 0.0641, loss intra: 0.0603, loss_inter 0.0038, lr 0.000010, time 0.60
# [23/24][242/313], loss 0.0695, loss intra: 0.0536, loss_inter 0.0159, lr 0.000010, time 0.61
# [23/24][243/313], loss 0.0635, loss intra: 0.0538, loss_inter 0.0096, lr 0.000010, time 0.60
# [23/24][244/313], loss 0.0650, loss intra: 0.0486, loss_inter 0.0164, lr 0.000010, time 0.60
# [23/24][245/313], loss 0.0819, loss intra: 0.0577, loss_inter 0.0242, lr 0.000010, time 0.60
# [23/24][246/313], loss 0.0699, loss intra: 0.0553, loss_inter 0.0146, lr 0.000010, time 0.60
# [23/24][247/313], loss 0.0630, loss intra: 0.0555, loss_inter 0.0075, lr 0.000010, time 0.58
# [23/24][248/313], loss 0.0834, loss intra: 0.0652, loss_inter 0.0182, lr 0.000010, time 0.58
# [23/24][249/313], loss 0.0578, loss intra: 0.0505, loss_inter 0.0073, lr 0.000010, time 0.60
# [23/24][250/313], loss 0.0780, loss intra: 0.0712, loss_inter 0.0068, lr 0.000010, time 0.60
# [23/24][251/313], loss 0.0734, loss intra: 0.0620, loss_inter 0.0114, lr 0.000010, time 0.61
# [23/24][252/313], loss 0.0846, loss intra: 0.0585, loss_inter 0.0261, lr 0.000010, time 0.61
# [23/24][253/313], loss 0.0809, loss intra: 0.0719, loss_inter 0.0090, lr 0.000010, time 0.60
# [23/24][254/313], loss 0.0717, loss intra: 0.0642, loss_inter 0.0075, lr 0.000010, time 0.60
# [23/24][255/313], loss 0.0656, loss intra: 0.0606, loss_inter 0.0050, lr 0.000010, time 0.60
# [23/24][256/313], loss 0.0974, loss intra: 0.0602, loss_inter 0.0372, lr 0.000010, time 0.60
# [23/24][257/313], loss 0.0509, loss intra: 0.0458, loss_inter 0.0051, lr 0.000010, time 0.60
# [23/24][258/313], loss 0.1005, loss intra: 0.0790, loss_inter 0.0215, lr 0.000010, time 0.60
# [23/24][259/313], loss 0.0903, loss intra: 0.0739, loss_inter 0.0164, lr 0.000010, time 0.60
# [23/24][260/313], loss 0.0639, loss intra: 0.0579, loss_inter 0.0060, lr 0.000010, time 0.60
# [23/24][261/313], loss 0.0699, loss intra: 0.0606, loss_inter 0.0093, lr 0.000010, time 0.59
# [23/24][262/313], loss 0.0701, loss intra: 0.0647, loss_inter 0.0053, lr 0.000010, time 0.59
# [23/24][263/313], loss 0.0530, loss intra: 0.0417, loss_inter 0.0112, lr 0.000010, time 0.61
# [23/24][264/313], loss 0.0906, loss intra: 0.0836, loss_inter 0.0070, lr 0.000010, time 0.60
# [23/24][265/313], loss 0.0668, loss intra: 0.0599, loss_inter 0.0069, lr 0.000010, time 0.59
# [23/24][266/313], loss 0.0602, loss intra: 0.0556, loss_inter 0.0046, lr 0.000010, time 0.60
# [23/24][267/313], loss 0.0680, loss intra: 0.0583, loss_inter 0.0097, lr 0.000010, time 0.59
# [23/24][268/313], loss 0.0643, loss intra: 0.0588, loss_inter 0.0055, lr 0.000010, time 0.60
# [23/24][269/313], loss 0.0620, loss intra: 0.0569, loss_inter 0.0050, lr 0.000010, time 0.60
# [23/24][270/313], loss 0.0706, loss intra: 0.0622, loss_inter 0.0084, lr 0.000010, time 0.58
# [23/24][271/313], loss 0.0756, loss intra: 0.0537, loss_inter 0.0219, lr 0.000010, time 0.58
# [23/24][272/313], loss 0.0610, loss intra: 0.0538, loss_inter 0.0072, lr 0.000010, time 0.61
# [23/24][273/313], loss 0.0580, loss intra: 0.0483, loss_inter 0.0096, lr 0.000010, time 0.61
# [23/24][274/313], loss 0.0732, loss intra: 0.0629, loss_inter 0.0104, lr 0.000010, time 0.60
# [23/24][275/313], loss 0.0731, loss intra: 0.0610, loss_inter 0.0121, lr 0.000010, time 0.60
# [23/24][276/313], loss 0.0669, loss intra: 0.0593, loss_inter 0.0076, lr 0.000010, time 0.60
# [23/24][277/313], loss 0.0690, loss intra: 0.0613, loss_inter 0.0076, lr 0.000010, time 0.60
# [23/24][278/313], loss 0.0501, loss intra: 0.0459, loss_inter 0.0041, lr 0.000010, time 0.60
# [23/24][279/313], loss 0.0741, loss intra: 0.0618, loss_inter 0.0123, lr 0.000010, time 0.60
# [23/24][280/313], loss 0.0741, loss intra: 0.0700, loss_inter 0.0041, lr 0.000010, time 0.60
# [23/24][281/313], loss 0.0561, loss intra: 0.0519, loss_inter 0.0042, lr 0.000010, time 0.60
# [23/24][282/313], loss 0.0758, loss intra: 0.0692, loss_inter 0.0066, lr 0.000010, time 0.60
# [23/24][283/313], loss 0.0740, loss intra: 0.0662, loss_inter 0.0078, lr 0.000010, time 0.60
# [23/24][284/313], loss 0.0847, loss intra: 0.0744, loss_inter 0.0103, lr 0.000010, time 0.60
# [23/24][285/313], loss 0.0719, loss intra: 0.0625, loss_inter 0.0094, lr 0.000010, time 0.60
# [23/24][286/313], loss 0.0577, loss intra: 0.0484, loss_inter 0.0093, lr 0.000010, time 0.60
# [23/24][287/313], loss 0.0761, loss intra: 0.0614, loss_inter 0.0146, lr 0.000010, time 0.60
# [23/24][288/313], loss 0.0928, loss intra: 0.0606, loss_inter 0.0322, lr 0.000010, time 0.60
# [23/24][289/313], loss 0.0834, loss intra: 0.0617, loss_inter 0.0217, lr 0.000010, time 0.60
# [23/24][290/313], loss 0.0682, loss intra: 0.0559, loss_inter 0.0123, lr 0.000010, time 0.61
# [23/24][291/313], loss 0.0730, loss intra: 0.0643, loss_inter 0.0087, lr 0.000010, time 0.59
# [23/24][292/313], loss 0.0838, loss intra: 0.0723, loss_inter 0.0115, lr 0.000010, time 0.59
# [23/24][293/313], loss 0.0728, loss intra: 0.0663, loss_inter 0.0065, lr 0.000010, time 0.57
# [23/24][294/313], loss 0.0539, loss intra: 0.0494, loss_inter 0.0046, lr 0.000010, time 0.58
# [23/24][295/313], loss 0.0655, loss intra: 0.0603, loss_inter 0.0052, lr 0.000010, time 0.60
# [23/24][296/313], loss 0.0838, loss intra: 0.0743, loss_inter 0.0095, lr 0.000010, time 0.61
# [23/24][297/313], loss 0.0618, loss intra: 0.0451, loss_inter 0.0167, lr 0.000010, time 0.62
# [23/24][298/313], loss 0.0705, loss intra: 0.0646, loss_inter 0.0060, lr 0.000010, time 0.61
# [23/24][299/313], loss 0.0692, loss intra: 0.0642, loss_inter 0.0050, lr 0.000010, time 0.60
# [23/24][300/313], loss 0.0859, loss intra: 0.0714, loss_inter 0.0145, lr 0.000010, time 0.59
# [23/24][301/313], loss 0.0681, loss intra: 0.0622, loss_inter 0.0059, lr 0.000010, time 0.61
# [23/24][302/313], loss 0.0774, loss intra: 0.0671, loss_inter 0.0103, lr 0.000010, time 0.60
# [23/24][303/313], loss 0.0797, loss intra: 0.0645, loss_inter 0.0152, lr 0.000010, time 0.60
# [23/24][304/313], loss 0.0588, loss intra: 0.0524, loss_inter 0.0064, lr 0.000010, time 0.60
# [23/24][305/313], loss 0.0727, loss intra: 0.0620, loss_inter 0.0107, lr 0.000010, time 0.61
# [23/24][306/313], loss 0.0715, loss intra: 0.0625, loss_inter 0.0090, lr 0.000010, time 0.60
# [23/24][307/313], loss 0.0579, loss intra: 0.0526, loss_inter 0.0054, lr 0.000010, time 0.61
# [23/24][308/313], loss 0.0640, loss intra: 0.0588, loss_inter 0.0052, lr 0.000010, time 0.61
# [23/24][309/313], loss 0.0622, loss intra: 0.0548, loss_inter 0.0074, lr 0.000010, time 0.61
# [23/24][310/313], loss 0.0546, loss intra: 0.0482, loss_inter 0.0064, lr 0.000010, time 0.61
# [23/24][311/313], loss 0.0836, loss intra: 0.0657, loss_inter 0.0180, lr 0.000010, time 0.60
# [23/24][312/313], loss 0.0831, loss intra: 0.0737, loss_inter 0.0094, lr 0.000010, time 0.30
# trained_augmented_checkpoint.pth
